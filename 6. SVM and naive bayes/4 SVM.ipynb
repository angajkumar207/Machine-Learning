# %% [markdown]
# SVM

# %% [markdown]
# Import all The required libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### load the data

# %%
data = pd.read_csv(r"C:\Users\angaj\Downloads\WineQT (1).csv")

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
data.drop(columns='Id', axis=1, inplace=True)

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
### EDA task

# %% [markdown]
# ### Data Splitting

# %%
x = data.drop(columns='quality', axis=1)
y = data['quality']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=1)

# %% [markdown]
# ### Data Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test =  scaler.transform(x_test)

# %% [markdown]
# ### Model Training: SVC classifier

# %%
from sklearn.svm import SVC
svm_classifier = SVC()
svm_classifier.fit(x_train, y_train)
# Out:
# SVC()

# %% [markdown]
# ### Model Prediction

# %%
y_predict = svm_classifier.predict(x_test)
y_predict
# Out:
# array([6, 5, 6, 6, 5, 7, 5, 6, 6, 5, 6, 5, 5, 6, 7, 6, 6, 5, 5, 6, 5, 6,
#        5, 6, 6, 6, 5, 6, 6, 6, 5, 6, 7, 5, 5, 5, 6, 6, 5, 5, 7, 6, 7, 6,
#        6, 6, 6, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 6, 5, 6, 6, 6, 5, 6,
#        5, 5, 6, 5, 6, 6, 6, 5, 5, 5, 5, 5, 5, 6, 5, 5, 6, 5, 6, 6, 5, 5,
#        5, 6, 5, 6, 6, 7, 5, 5, 6, 7, 6, 5, 6, 7, 6, 7, 5, 6, 6, 5, 5, 6,
#        6, 5, 6, 5, 7, 5, 5, 5, 6, 6, 5, 5, 6, 6, 5, 5, 5, 5, 5, 5, 5, 6,
#        5, 6, 7, 6, 5, 5, 6, 5, 6, 6, 6, 5, 5, 7, 6, 5, 5, 6, 7, 5, 5, 5,
#        5, 6, 6, 5, 6, 5, 5, 6, 5, 5, 5, 5, 5, 6, 5, 6, 5, 6, 5, 7, 5, 6,
#        6, 6, 6, 7, 6, 7, 6, 7, 5, 6, 7, 6, 5, 6, 6, 5, 6, 6, 6, 6, 6, 6,
#        5, 5, 6, 5, 6, 5, 6, 6, 6, 5, 5, 5, 5, 5, 5, 5, 7, 6, 6, 5, 5, 6,
#        6, 6, 5, 5, 6, 7, 7, 5, 6], dtype=int64)

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_predict)
print(accuracy)
# Out:
# 0.6419213973799127

# %% [markdown]
# ### Hyperparameter Tuning: GridsearchCV

# %%
parameters = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto'],
    'degree': [2, 3, 5, ]
}

from sklearn.model_selection import GridSearchCV
grid_search =  GridSearchCV(svm_classifier, parameters)
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10], 'degree': [2, 3, 5],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
grid_search.best_params_
# Out:
# {'C': 1, 'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}

# %%
svm_classifier =  SVC(degree=2)
svm_classifier.fit(x_train ,y_train)
# Out:
# SVC(degree=2)

# %%
y_prediction  = svm_classifier.predict(x_test)
y_prediction
# Out:
# array([6, 5, 6, 6, 5, 7, 5, 6, 6, 5, 6, 5, 5, 6, 7, 6, 6, 5, 5, 6, 5, 6,
#        5, 6, 6, 6, 5, 6, 6, 6, 5, 6, 7, 5, 5, 5, 6, 6, 5, 5, 7, 6, 7, 6,
#        6, 6, 6, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 6, 5, 6, 6, 6, 5, 6,
#        5, 5, 6, 5, 6, 6, 6, 5, 5, 5, 5, 5, 5, 6, 5, 5, 6, 5, 6, 6, 5, 5,
#        5, 6, 5, 6, 6, 7, 5, 5, 6, 7, 6, 5, 6, 7, 6, 7, 5, 6, 6, 5, 5, 6,
#        6, 5, 6, 5, 7, 5, 5, 5, 6, 6, 5, 5, 6, 6, 5, 5, 5, 5, 5, 5, 5, 6,
#        5, 6, 7, 6, 5, 5, 6, 5, 6, 6, 6, 5, 5, 7, 6, 5, 5, 6, 7, 5, 5, 5,
#        5, 6, 6, 5, 6, 5, 5, 6, 5, 5, 5, 5, 5, 6, 5, 6, 5, 6, 5, 7, 5, 6,
#        6, 6, 6, 7, 6, 7, 6, 7, 5, 6, 7, 6, 5, 6, 6, 5, 6, 6, 6, 6, 6, 6,
#        5, 5, 6, 5, 6, 5, 6, 6, 6, 5, 5, 5, 5, 5, 5, 5, 7, 6, 6, 5, 5, 6,
#        6, 6, 5, 5, 6, 7, 7, 5, 6], dtype=int64)

# %%
accuracy_value = accuracy_score(y_test, y_prediction)
print(accuracy_value)
# Out:
# 0.6419213973799127

# %% [markdown]
# ### Randomized SerchCV

# %%
parameters = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto'],
    'degree': [2, 3, 5]
}

from sklearn.model_selection import RandomizedSearchCV
random_search =  GridSearchCV(svm_classifier, parameters)
random_search.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=SVC(degree=2),
#              param_grid={'C': [0.1, 1, 10], 'degree': [2, 3, 5],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
random_search.best_params_
# Out:
# {'C': 1, 'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}
